# %%
import pandas as pd
import seaborn as sns
import numpy as np
import dc_stat_think as dcst
import matplotlib.pyplot as plt

## Pandas lecturas de archivos planos 
## seaborn creacion de graficos

# %%
## crear variable
## el punto signigica que se aplicara una funcion y se aplica a un objeto


df =sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df[df.sepal_length > 6]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 56            6.3          3.3           4.7          1.6  versicolor
# ..            ...          ...           ...          ...         ...
# 144           6.7          3.3           5.7          2.5   virginica
# 145           6.7          3.0           5.2          2.3   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 147           6.5          3.0           5.2          2.0   virginica
# 148           6.2          3.4           5.4          2.3   virginica
#
# [61 rows x 5 columns]

# %%
df[(df.sepal_length > 3) & (df.petal_length < 3)]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
df[df.species == 'virginica']

## llamar una variable especifica de un conjunto de datos

# %%
df.sample(frac=0.5)  ## se muestran de manera aleatoria
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 110           6.5          3.2           5.1          2.0   virginica
# 119           6.0          2.2           5.0          1.5   virginica
# 127           6.1          3.0           4.9          1.8   virginica
# 33            5.5          4.2           1.4          0.2      setosa
# 25            5.0          3.0           1.6          0.2      setosa
# ..            ...          ...           ...          ...         ...
# 134           6.1          2.6           5.6          1.4   virginica
# 144           6.7          3.3           5.7          2.5   virginica
# 59            5.2          2.7           3.9          1.4  versicolor
# 6             4.6          3.4           1.4          0.3      setosa
# 31            5.4          3.4           1.5          0.4      setosa
#
# [75 rows x 5 columns]

# %%
## llamar una cantidad de la muestra

df.sample(n=10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 50            7.0          3.2           4.7          1.4  versicolor
# 10            5.4          3.7           1.5          0.2      setosa
# 70            5.9          3.2           4.8          1.8  versicolor
# 90            5.5          2.6           4.4          1.2  versicolor
# 6             4.6          3.4           1.4          0.3      setosa
# 88            5.6          3.0           4.1          1.3  versicolor
# 122           7.7          2.8           6.7          2.0   virginica
# 84            5.4          3.0           4.5          1.5  versicolor
# 100           6.3          3.3           6.0          2.5   virginica
# 62            6.0          2.2           4.0          1.0  versicolor

# %%
## funcion iloc para llamar las filas y columnas

df.iloc[10:20]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# 13           4.3          3.0           1.1          0.1  setosa
# 14           5.8          4.0           1.2          0.2  setosa
# 15           5.7          4.4           1.5          0.4  setosa
# 16           5.4          3.9           1.3          0.4  setosa
# 17           5.1          3.5           1.4          0.3  setosa
# 18           5.7          3.8           1.7          0.3  setosa
# 19           5.1          3.8           1.5          0.3  setosa

# %%
df.nlargest(10,'sepal_length')
## mostrar los primeros 10 resultados mas grandes de la variable sepal_length
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 125           7.2          3.2           6.0          1.8  virginica

# %%
df.nsmallest(10,'sepal_length')
## mostrar los primeros 10 resultados mas pequeños de la variable sepal_length
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 13           4.3          3.0           1.1          0.1  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 38           4.4          3.0           1.3          0.2  setosa
# 42           4.4          3.2           1.3          0.2  setosa
# 41           4.5          2.3           1.3          0.3  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 22           4.6          3.6           1.0          0.2  setosa
# 47           4.6          3.2           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
